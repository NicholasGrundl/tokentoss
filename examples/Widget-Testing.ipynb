# %%
from tokentoss import GoogleAuthWidget

## Make up a client secrets file to test the GUI
# import json
# import pathlib
# secrets_file = pathlib.Path("./client_secrets_example.json")
# secrets_file.write_text(json.dumps({
#     "installed": {
#         "client_id": "test-client-id.apps.googleusercontent.com",
#         "client_secret": "test-secret",
#         "auth_uri": "https://accounts.google.com/o/oauth2/auth",
#         "token_uri": "https://oauth2.googleapis.com/token",
#         "redirect_uris": ["http://localhost"],
#     }
# }))

# %%
# You'll need a client_secrets.json file for real OAuth                                                
# For now, just test the widget renders:                                                               
widget = GoogleAuthWidget(client_secrets_path="./client_secrets.json")                                 
display(widget)

# %%
auth_manager = widget.auth_manager
display(f"Is Authenticated: {auth_manager.is_authenticated}")
display(f"User Email: {auth_manager.user_email}")
# Out:
# 'Is Authenticated: True'
# 'User Email: nicholasgrundl@gmail.com'
